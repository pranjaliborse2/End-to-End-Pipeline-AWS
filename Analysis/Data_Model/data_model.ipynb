# %%
import pandas as pd
import numpy as np
import psycopg2
import pyarrow.parquet as pq
import polars as pl
import duckdb

# %%
# Read policy table to know the Schema and select required columns. (Raw Data is preloaded using direct download from NFIP web)
policies = pq.ParquetFile(r"D:\Self projects\Flood Insurance SQL-Python\data\FimaNfipPolicies.parquet")
schema = policies.schema

print(schema)
# Out:
# <pyarrow._parquet.ParquetSchema object at 0x000001F7DBD72280>
# required group field_id=-1 duckdb_schema {
#   optional boolean field_id=-1 agricultureStructureIndicator;
#   optional int32 field_id=-1 baseFloodElevation (Decimal(precision=8, scale=2));
#   optional int32 field_id=-1 basementEnclosureCrawlspaceType (Int(bitWidth=16, isSigned=true));
#   optional int32 field_id=-1 cancellationDateOfFloodPolicy (Date);
#   optional binary field_id=-1 condominiumCoverageTypeCode (String);
#   optional boolean field_id=-1 construction;
#   optional int32 field_id=-1 crsClassCode (Int(bitWidth=16, isSigned=true));
#   optional binary field_id=-1 buildingDeductibleCode (String);
#   optional binary field_id=-1 contentsDeductibleCode (String);
#   optional boolean field_id=-1 elevatedBuildingIndicator;
#   optional binary field_id=-1 elevationCertificateIndicator (String);
#   optional int32 field_id=-1 elevationDifference (Int(bitWidth=32, isSigned=true));
#   optional int32 field_id=-1 federalPolicyFee (Int(bitWidth=16, isSigned=true));
#   optional binary field_id=-1 ratedFloodZone (String);
#   optional int32 field_id=-1 hfiaaSurcharge (Int(bitWidth=16, isSigned=true));
#   optional boolean field_id=-1 houseOfWorshipIndicator;
#   optional int32 field_id=-1 locationOfContents (Int(bitWidth=16, isSigned=true));
#   optional int32 field_id=-1 lowestAdjacentGrade (Decimal(precision=8, scale=2));
#   optional int32 field_id=-1 lowestFloorElevation (Decimal(precision=8, scale=2));
#   optional boolean field_id=-1 nonProfitIndicator;
#   optional int32 field_id=-1 numberOfFloorsInInsuredBuilding (Int(bitWidth=16, isSigned=true));
#   optional int32 field_id=-1 obstructionType (Int(bitWidth=16, isSigned=true));
#   optional int32 field_id=-1 occupancyType (Int(bitWidth=16, isSigned=true));
#   optional int32 field_id=-1 originalConstructionDate (Date);
#   optional int32 field_id=-1 originalNBDate (Date);
#   optional int32 field_id=-1 policyCost (Int(bitWidth=32, isSigned=true));
#   optional int32 field_id=-1 policyCount (Int(bitWidth=16, isSigned=true));
#   optional int32 field_id=-1 policyEffectiveDate (Date);
#   optional int32 field_id=-1 policyTerminationDate (Date);
#   optional int32 field_id=-1 policyTermIndicator (Int(bitWidth=16, isSigned=true));
#   optional boolean field_id=-1 postFIRMConstructionIndicator;
#   optional boolean field_id=-1 primaryResidenceIndicator;
#   optional binary field_id=-1 rateMethod (String);
#   optional binary field_id=-1 regularEmergencyProgramIndicator (String);
#   optional boolean field_id=-1 smallBusinessIndicatorBuilding;
#   optional int32 field_id=-1 totalBuildingInsuranceCoverage (Int(bitWidth=32, isSigned=true));
#   optional int32 field_id=-1 totalContentsInsuranceCoverage (Int(bitWidth=32, isSigned=true));
#   optional int32 field_id=-1 totalInsurancePremiumOfThePolicy (Int(bitWidth=32, isSigned=true));
#   optional binary field_id=-1 cancellationVoidanceReasonCode (String);
#   optional binary field_id=-1 subsidizedRateType (String);
#   optional int32 field_id=-1 iccPremium (Int(bitWidth=16, isSigned=true));
#   optional int32 field_id=-1 reserveFundAssessment (Int(bitWidth=32, isSigned=true));
#   optional int32 field_id=-1 communityProbationSurcharge (Int(bitWidth=16, isSigned=true));
#   optional int32 field_id=-1 premiumPaymentIndicator (Int(bitWidth=16, isSigned=true));
#   optional int64 field_id=-1 buildingReplacementCost (Int(bitWidth=64, isSigned=true));
#   optional int32 field_id=-1 basicBuildingRate (Decimal(precision=8, scale=2));
#   optional int32 field_id=-1 additionalBuildingRate (Decimal(precision=8, scale=2));
#   optional int32 field_id=-1 basicContentsRate (Decimal(precision=8, scale=2));
#   optional int32 field_id=-1 AdditionalContentsRate (Decimal(precision=8, scale=2));
#   optional binary field_id=-1 enclosureTypeCode (String);
#   optional int32 field_id=-1 buildingDescriptionCode (Int(bitWidth=16, isSigned=true));
#   optional int32 field_id=-1 insuranceToValueCode (Int(bitWidth=16, isSigned=true));
#   optional boolean field_id=-1 postFirmVzoneIndicator;
#   optional boolean field_id=-1 floodproofedIndicator;
#   optional binary field_id=-1 waitingPeriodType (String);
#   optional binary field_id=-1 rolloverTransferCode (String);
#   optional int32 field_id=-1 endorsementEffectiveDate (Date);
#   optional int32 field_id=-1 propertyPurchaseDate (Date);
#   optional boolean field_id=-1 rentalPropertyIndicator;
#   optional boolean field_id=-1 tenantIndicator;
#   optional boolean field_id=-1 stateOwnedIndicator;
#   optional int32 field_id=-1 disasterAssistanceCoverageRequiredCode (Int(bitWidth=16, isSigned=true));
#   optional boolean field_id=-1 mandatoryPurchaseFlag;
#   optional int32 field_id=-1 grandfatheringTypeCode (Int(bitWidth=16, isSigned=true));
#   optional binary field_id=-1 nfipRatedCommunityNumber (String);
#   optional binary field_id=-1 nfipCommunityNumberCurrent (String);
#   optional binary field_id=-1 nfipCommunityName (String);
#   optional boolean field_id=-1 programTypeIndicator;
#   optional binary field_id=-1 mapPanelNumber (String);
#   optional binary field_id=-1 mapPanelSuffix (String);
#   optional binary field_id=-1 floodZoneCurrent (String);
#   optional int32 field_id=-1 femaRegion (Int(bitWidth=16, isSigned=true));
#   optional binary field_id=-1 propertyState (String);
#   optional binary field_id=-1 reportedCity (String);
#   optional binary field_id=-1 reportedZipCode (String);
#   optional binary field_id=-1 countyCode (String);
#   optional binary field_id=-1 censusTract (String);
#   optional binary field_id=-1 censusBlockGroupFips (String);
#   optional int32 field_id=-1 latitude (Decimal(precision=9, scale=1));
#   optional int32 field_id=-1 longitude (Decimal(precision=9, scale=1));
#   optional fixed_len_byte_array(16) field_id=-1 id (UUID);
# }

# %%
#  COLUMNS TO RETAIN 
selected_columns = [
    "id",
    "reportedZipCode",
    "propertyState",
    "reportedCity",
    "countyCode",
    "latitude",
    "longitude",
    "policyEffectiveDate",
    "policyTerminationDate",
    "propertyPurchaseDate",
    "totalBuildingInsuranceCoverage",
    "totalContentsInsuranceCoverage",
    "totalInsurancePremiumOfThePolicy",
    "buildingReplacementCost",
    "occupancyType",
    "construction",
    "numberOfFloorsInInsuredBuilding",
    "lowestFloorElevation",
    "elevatedBuildingIndicator",
    "floodproofedIndicator",
    "postFIRMConstructionIndicator",
    "policyTermIndicator",
    "rateMethod",
    "programTypeIndicator",
    "nfipRatedCommunityNumber"
]

#  LOAD & SAVE WITH duckdb
con = duckdb.connect("D:\Self projects\Flood Insurance SQL-Python\data\insurance.duckdb")

# con.sql("""
#         CREATE TABLE IF NOT EXISTS policies
#         as from read_parquet("D:\Self projects\Flood Insurance SQL-Python\data\FimaNfipPolicies.parquet")
#         """)

# %%
[print(i,',') for i in selected_columns];
# Out:
# id ,
# reportedZipCode ,
# propertyState ,
# reportedCity ,
# countyCode ,
# latitude ,
# longitude ,
# policyEffectiveDate ,
# policyTerminationDate ,
# propertyPurchaseDate ,
# totalBuildingInsuranceCoverage ,
# totalContentsInsuranceCoverage ,
# totalInsurancePremiumOfThePolicy ,
# buildingReplacementCost ,
# occupancyType ,
# construction ,
# numberOfFloorsInInsuredBuilding ,
# lowestFloorElevation ,
# elevatedBuildingIndicator ,
# floodproofedIndicator ,
# postFIRMConstructionIndicator ,
# policyTermIndicator ,
# rateMethod ,
# programTypeIndicator ,
# nfipRatedCommunityNumber ,

# %%
sel_policies = con.sql("""
                        select 
                    id ,
                    reportedZipCode ,
                    propertyState ,
                    reportedCity ,
                    countyCode ,
                    latitude ,
                    longitude ,
                    policyEffectiveDate ,
                    policyTerminationDate ,
                    propertyPurchaseDate ,
                    totalBuildingInsuranceCoverage ,
                    totalContentsInsuranceCoverage ,
                    totalInsurancePremiumOfThePolicy ,
                    buildingReplacementCost ,
                    occupancyType ,
                    construction ,
                    numberOfFloorsInInsuredBuilding ,
                    lowestFloorElevation ,
                    elevatedBuildingIndicator ,
                    floodproofedIndicator ,
                    postFIRMConstructionIndicator ,
                    policyTermIndicator ,
                    rateMethod ,
                    programTypeIndicator ,
                    nfipRatedCommunityNumber
                        
                    From policies
                       
                    where propertyState in ('Tx','TX','LA','FL','NY','CA')
                    """)

# %%
con.sql("""
        select DISTINCT propertyState 
        from sel_policies
        """).df()['propertyState'].values
# Out:
# array(['FL', 'TX', 'NY', 'LA', 'Tx', 'CA'], dtype=object)

# %%
states = ['TX','LA','FL','NY','CA']

# %%
## Create a CSV file of the policies data per selected state with selected columns
for state in states:
  con.sql(f"""
          COPY (
            SELECT * FROM sel_policies
            where propertyState = '{state}'
          ) TO "nfip_policies_{state}.csv" (HEADER, DELIMITER ',');
          """)

# %%
#Load the data into postgresql

from dotenv import load_dotenv
import os

#Create secure connection
load_dotenv('credentials.env')

try:
    post_con = psycopg2.connect(host = os.getenv('PG_HOST'), 
                            dbname = os.getenv('PG_DB'), 
                            user = os.getenv('PG_USER'), 
                            password = os.getenv('PG_PASSWORD'))
except psycopg2.Error as e:
    print(e)

# %%
# Get the cursor to execute SQL queries using the connection made above
cur = post_con.cursor()

# set autocommit = True to not save every query manually
post_con.set_session(autocommit=True)

# %%
# Create a database & connect to the new database by closing the connection to default database

try:
    cur.execute("Create database NFIP_Policies")
except psycopg2.Error as e:
    print(e)
post_con.close()

# Connect to new database just created (Database name is read in all small case letters)
try:
    post_con = psycopg2.connect(host = os.getenv('PG_HOST'), 
                            dbname = 'nfip_policies', 
                            user = os.getenv('PG_USER'), 
                            password = os.getenv('PG_PASSWORD'))
except psycopg2.Error as e:
    print(e)
# Out:
# database "nfip_policies" already exists

# %%
# Create a new cursor for new database
cur = post_con.cursor()
post_con.set_session(autocommit=True)

# %%
# create policies table into database using a data model
for state in states:
    cur.execute(f""" CREATE TABLE policies_{state} 
                (id UUID PRIMARY KEY,
                reportedZipCode TEXT,
                propertyState TEXT,
                reportedCity TEXT,
                countyCode TEXT,
                latitude NUMERIC(9,1),
                longitude NUMERIC(9,1),
                policyEffectiveDate DATE,
                policyTerminationDate DATE,
                propertyPurchaseDate DATE,
                totalBuildingInsuranceCoverage INTEGER,
                totalContentsInsuranceCoverage INTEGER,
                totalInsurancePremiumOfThePolicy INTEGER,
                buildingReplacementCost BIGINT,
                occupancyType SMALLINT,
                construction BOOLEAN,
                numberOfFloorsInInsuredBuilding SMALLINT,
                lowestFloorElevation NUMERIC(8,2),
                elevatedBuildingIndicator BOOLEAN,
                floodproofedIndicator BOOLEAN,
                postFIRMConstructionIndicator BOOLEAN,
                policyTermIndicator SMALLINT,
                rateMethod TEXT,
                programTypeIndicator BOOLEAN,
                nfipRatedCommunityNumber TEXT
                );
                """)

# %%
# Insert the policies data from the CSV file
state_policies = os.listdir('Data')
for file,state in zip(state_policies,sorted(states)):
    with open(f"Data\{file}", "r") as f:
        cur.copy_expert(f"""
            COPY policies_{state} FROM STDIN WITH CSV HEADER
        """, f)

# %%
# cur.execute("select * from policies_ca")

# %%
# Check if data is loaded to the table 
## cur.fetchone() OR cur.fetchall() OR
pd.read_sql("SELECT * FROM policies_ca LIMIT 10;", post_con)
# Out:
# C:\Users\pranj\AppData\Local\Temp\ipykernel_30252\3881968528.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql("SELECT * FROM policies LIMIT 10;", post_con)
#                                      id reportedzipcode propertystate  \
# 0  8c56361f-c29d-4321-a203-219b3b3af875           77651            TX
# 1  3cfae310-e162-412d-818d-7744d2761c14           77651            TX
# 2  78470d8d-aefc-43ac-9ab5-477a8225df1e           77651            TX
# 3  0cf829af-c9c6-4068-b373-b5fb36593173           77651            TX
# 4  cadb086f-3f85-4044-b7cb-0484ab74c676           77651            TX
# 5  207b74fd-088d-4d5f-b73d-b18d600a720b           77651            TX
# 6  f979b37d-863c-4872-aa4e-94bb603f6f59           77651            TX
# 7  11f3cda4-b9c5-4227-abc4-74cc13864f33           77651            TX
# 8  00bb90ba-5ba9-4dd7-b12a-cae842d387a5           77651            TX
# 9  76024b5c-ad0e-4700-ba2c-8c04072b2868           77651            TX
#
#             reportedcity countycode  latitude  longitude policyeffectivedate  \
# 0  Currently Unavailable      48245      30.0      -94.0          2021-05-16
# 1  Currently Unavailable      48245      30.0      -94.0          2021-06-15
# 2  Currently Unavailable      48245      30.0      -94.0          2021-06-22
# 3  Currently Unavailable      48245      30.0      -94.0          2021-08-16
# 4  Currently Unavailable      48245      30.0      -94.0          2021-05-07
# 5  Currently Unavailable      48245      30.0      -94.0          2021-09-02
# 6  Currently Unavailable      48245      30.0      -94.0          2021-07-23
# 7  Currently Unavailable      48245      30.0      -94.0          2021-06-05
# 8  Currently Unavailable      48245      30.0      -94.0          2021-07-20
# 9  Currently Unavailable      48245      30.0      -94.0          2021-05-30
#
#   policyterminationdate propertypurchasedate  ...  construction  \
# 0            2022-05-16           2021-04-16  ...         False
# 1            2022-06-15           2018-01-01  ...         False
# 2            2022-06-22                 None  ...         False
# 3            2022-08-16           1992-04-01  ...         False
# 4            2022-05-07           2021-05-07  ...         False
# 5            2022-09-02                 None  ...         False
# 6            2022-07-23           2014-07-01  ...         False
# 7            2022-06-05           2001-01-01  ...         False
# 8            2022-07-20           2015-04-15  ...         False
# 9            2022-05-30                 None  ...         False
#
#    numberoffloorsininsuredbuilding  lowestfloorelevation  \
# 0                                2                  None
# 1                                1                  None
# 2                                2                  None
# 3                                1                  None
# 4                                1                  None
# 5                                1                  None
# 6                                1                  None
# 7                                1                  None
# 8                                1                  None
# 9                                1                  None
#
#    elevatedbuildingindicator  floodproofedindicator  \
# 0                      False                  False
# 1                      False                  False
# 2                      False                  False
# 3                      False                  False
# 4                      False                  False
# 5                      False                  False
# 6                      False                  False
# 7                      False                  False
# 8                      False                  False
# 9                      False                  False
#
#    postfirmconstructionindicator  policytermindicator ratemethod  \
# 0                           True                    1          7
# 1                           True                    1          7
# 2                           True                    1          7
# 3                           True                    1          7
# 4                          False                    1          7
# 5                          False                    1          7
# 6                           True                    1          7
# 7                           True                    1          7
# 8                           True                    1          7
# 9                           True                    1          7
#
#    programtypeindicator  nfipratedcommunitynumber
# 0                 False                    485500
# 1                 False                    485500
# 2                 False                    485500
# 3                 False                    485500
# 4                 False                    485500
# 5                 False                    485500
# 6                 False                    485500
# 7                 False                    485500
# 8                 False                    485500
# 9                 False                    485500
#
# [10 rows x 25 columns]

# %%
# Now that relational database is ready, it is crucial to think about optimizing the performance as it is a huge dataset
# Optimization practice - Index the columns which will be frequently used for querying during analysis

def create_idx(attr):
    query  = f"CREATE INDEX IF NOT EXISTS idx_{attr} ON policies ({attr});"
    return query

idx_attr = ["reportedZipCode", "propertyState", "reportedCity", "policyEffectiveDate", "policyTerminationDate", "totalInsurancePremiumOfThePolicy"]
for attr in idx_attr:
    cur.execute(create_idx(attr))
